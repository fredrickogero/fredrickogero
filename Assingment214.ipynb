# %% [markdown]
# <a href="https://colab.research.google.com/github/fredrickogero/fredrickogero/blob/main/Assingment214.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
fredrick =pd.read_csv('/content/Road.csv')
fredrick
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
import pandas as pd

import pandas as pd
fredrick = pd.read_csv('/content/Road.csv')
fredrick1 = fredrick.loc[:, ['Accident_severity', 'Casualty_severity']]
fredrick1 =fredrick1['Casualty_severity'] = fredrick1['Casualty_severity'].fillna(0)
print(f"Missing values in 'Casualty_severity' before handling: {fredrick1['Casualty_severity'].isna().sum()}")
fredrick1['Casualty_severity'].fillna(0, inplace=True)
print(f"Missing values in 'Casualty_severity' after handling: {fredrick1['Casualty_severity'].isna().sum()}")
fredrick1.head(10)
# Out:
# Missing values in 'Casualty_severity' before handling: 0
# Missing values in 'Casualty_severity' after handling: 0
# 0    na
# 1    na
# 2     3
# 3     3
# 4    na
# 5     3
# 6     3
# 7    na
# 8     3
# 9     3
# Name: Casualty_severity, dtype: object

# %%
import pandas as pd
df = pd.read_csv("/content/Road.csv")
severity_mapping = {
    "Fatal": 3,
    "Serious": 2,
    "Slight": 1
}

df["Accident_severity"] = df["Accident_severity"].replace(severity_mapping)
df.to_csv("Road.CSV", index=True)
print(df.head(4))
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# 0            Owner              Above 10yr  ...   Going straight
# 1            Owner                 5-10yrs  ...   Going straight
# ...

# %%
import pandas as pd

# Load the dataset
fredrick2 = pd.read_csv("Road.csv")

# Define a mapping dictionary
severity_mapping = {
    "Slight Injury": 0,
    "Serious Injury": 1,
    "Fatal Injury": 2  # Include all possible categories
}

# Apply mapping
fredrick2["Accident_severity"] = fredrick2["Accident_severity"].map(severity_mapping)

# Fill NaN values with a default integer value
fredrick2["Accident_severity"] = fredrick2["Accident_severity"].fillna(-1).astype(int)

# Save the updated dataset
fredrick2.to_csv("Road_updated.csv", index=False)

# Display the first few rows
print(fredrick2.head())
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
import pandas as pd
df = pd.read_csv("/content/Road_updated.csv")
df_cleaned = df.dropna()
df_cleaned.to_csv("Road_cleaned.csv", index=False)
print(df_cleaned.head())
# Out:
#         Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 8   17:20:00      Friday              18-30          Male  Junior high school
# 9   17:20:00      Friday              18-30          Male  Junior high school
# 12  17:45:00    Thursday              18-30          Male  Junior high school
# 13  17:45:00    Thursday              31-50          Male  Junior high school
# 14  17:45:00    Thursday              31-50          Male  Junior high school
#
#    Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 8                 Employee         Above 10yr      Lorry (41?100Q)
# 9                 Employee              1-2yr           Automobile
# 12                Employee              1-2yr  Public (> 45 seats)
# 13                Employee             5-10yr      Lorry (41?100Q)
# 14                Employee         Above 10yr           Automobile
#
#    Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
import sys
sys.setrecursionlimit(2000)

fredrick2 =pd.read_csv('/content/Road_updated.csv')

fredrick2.plot(x='Number_of_casualties', y='Accident_severity', style='o')
# Separate the assignments to avoid recursion:
fredrick2['Casualty_severity'] = fredrick2['Casualty_severity'].fillna(0) # Fill NaN in fredrick2
df = fredrick2['Casualty_severity']  # Assign the 'Casualty_severity' column to df
df
# Out:
# 0        na
# 1        na
# 2         3
# 3         3
# 4        na
#          ..
# 12311    na
# 12312    na
# 12313     3
# 12314    na
# 12315     3
# Name: Casualty_severity, Length: 12316, dtype: object

# %%
df =df['Casualty_severity'] = df['Casualty_severity'].fillna(0)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
fredrick2 =pd.read_csv('/content/Road_updated.csv')
x = pd.DataFrame(fredrick2['Number_of_casualties'])
y = pd.DataFrame(fredrick2['Accident_severity'])
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)
print(y_pred)
# Out:
# [[0.08408064]
#  [0.13554924]
#  [0.09694779]
#  ...
#  [0.13554924]
#  [0.13554924]
#  [0.10981494]]

# %%
from sklearn import metrics
import numpy as np
mae = metrics.mean_absolute_error(y_test, y_pred)
print('Mean Absolute Error:', mae)
mse = metrics.mean_squared_error(y_test, y_pred)
print('Mean Squared Error:', mse)
rmse = np.sqrt(mse)
print('Root Mean Squared Error:', rmse)
# Out:
# Mean Absolute Error: 0.2445128352049308
# Mean Squared Error: 0.1353975852837816
# Root Mean Squared Error: 0.3679641086896677

# %%
import joblib
from sklearn.linear_model import LinearRegression
model =LinearRegression()
model.fit(x_train, y_train)
joblib.dump(model, 'model.pkl')
# Out:
# ['model.pkl']
